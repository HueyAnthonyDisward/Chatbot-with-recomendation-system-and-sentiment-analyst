# %%
import re
import pandas as pd

# Load the CSV file
file_path = "Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv"
df = pd.read_csv(file_path)

# Define a regex pattern to match placeholders including the {{}}
pattern = r'{{[^}]+}}'

# Extract all unique placeholders from the 'response' column
placeholders = set()
for response in df['response']:
    if isinstance(response, str):  # Ensure the value is a string
        matches = re.findall(pattern, response)
        placeholders.update(matches)

# Convert to a sorted list for better readability
unique_placeholders = sorted(list(placeholders))

# Print the unique placeholders
print("Unique custom placeholders found:")
for placeholder in unique_placeholders:
    print(placeholder)
# Out:
# Unique custom placeholders found:
# {{Access Key Recovery}}
# {{Access Key Reset Page URL}}
# {{Access Key Retrieval}}
# {{Access Key}}
# {{Account Access Key Reset}}
# {{Account Category}}
# {{Account Change}}
# {{Account Closure Process}}
# {{Account Closure Timeframe}}
# {{Account Details}}
# {{Account ID}}
# {{Account Key Recovery}}
# {{Account Management}}
# {{Account Name}}
# {{Account Number}}
# {{Account Page}}
# {{Account Plan}}
# {{Account Recovery Page URL}}
# {{Account Recovery Page}}
# {{Account Recovery}}
# {{Account Security}}
# {{Account Type Switch}}
# {{Account Type}}
# {{Account Upgrade}}
# {{Account}}
# {{Add a New Address}}
# {{Basic Account}}
# {{Basic}}
# {{Billing Category}}
# {{Billing History}}
# {{Billing}}
# {{Business Hours}}
# {{Business Name Anonymized}}
# {{Cancel Purchase}}
# {{Cancellation Policy}}
# {{Cancellation Refund Time}}
# {{Carrier Name}}
# {{Case Number}}
# {{Change Access Key}}
# {{Change Account}}
# {{Change Key}}
# {{Change PIN}}
# ...

# %%
# %%markdown
# # 📄 Placeholder Categories
#
# ## 🔐 Thông tin tài khoản (Account Information)
# - Account ID
# - Account Name
# - Account Number
# - Account Plan
# - Account Type
# - Account Category
#
# ## 🔒 Bảo mật tài khoản (Account Security)
# - Access Key
# - Change Access Key
# - Forgot Access Key
# - Password
# - Change Password
# - Forgot Password
# - PIN Code
# - Change PIN
# - Forgot PIN
# - Security Settings
#
# ## ♻️ Khôi phục tài khoản/thông tin đăng nhập (Account/Login Recovery)
# - Account Recovery Page URL
# - Forgot Account Access Key
# - Password Recovery Page URL
# - PIN Recovery Page URL
# - Recover Access Key
# - Recover PIN
#
# ## 👤 Quản lý hồ sơ người dùng (User/Profile Management)
# - Client First Name
# - Client Last Name
# - Profile Settings
# - Change Profile
# - Update Profile
# - User Account Settings
#
# ## 🏠 Địa chỉ (Address)
# - Add a New Address
# - Shipping Addresses
# - Delivery City
# - Delivery Country
# - Zip Code
#
# ## 💳 Thanh toán và hóa đơn (Billing & Invoices)
# - Billing History
# - Billing Category
# - Date of the Bill
# - Date of the Invoice
# - Invoice Number
#
# ## 📦 Đơn hàng và giao hàng (Orders & Delivery)
# - Order Number
# - Order Status
# - Track Order
# - Tracking Number
# - Delivery Date
# - Delivery Time
# - Shipping Method
# - Estimated Delivery Time
#
# ## 📞 Hỗ trợ khách hàng (Customer Support)
# - Contact Us
# - Contact Page URL
# - Customer Service Email
# - Customer Service Phone Number
# - Live Chat
# - Help Center URL
# - Support Hours
# - Support Phone Number
#
# ## 💰 Hoàn tiền và hủy đơn hàng (Refunds & Cancellations)
# - Refund Policy
# - Refund Amount
# - Cancellation Policy
# - Confirm Cancellation
# - Cancel Purchase
# - Refund Processing Time
#
# ## 🏢 Thông tin công ty (Company Information)
# - Company Name
# - Company Phone Number
# - Company Support Page URL
# - Business Hours
#
# ## 🧩 Các tính năng và chức năng (Features & Functionality)
# - Feature 1
# - Explanation of Feature 1
# - Live Chat Feature
# - Order Tracking
#
# ## 🗃️ Thông tin khác (Miscellaneous)
# - Currency Symbol
# - Date
# - Timeframe
# - Number of Days
# - Month
# - Year
# Out:
# # 📄 Placeholder Categories
#
# ## 🔐 Thông tin tài khoản (Account Information)
# - Account ID
# - Account Name
# - Account Number
# - Account Plan
# - Account Type
# - Account Category
#
# ## 🔒 Bảo mật tài khoản (Account Security)
# - Access Key
# - Change Access Key
# - Forgot Access Key
# - Password
# - Change Password
# - Forgot Password
# - PIN Code
# - Change PIN
# - Forgot PIN
# - Security Settings
#
# ## ♻️ Khôi phục tài khoản/thông tin đăng nhập (Account/Login Recovery)
# - Account Recovery Page URL
# - Forgot Account Access Key
# - Password Recovery Page URL
# - PIN Recovery Page URL
# - Recover Access Key
# - Recover PIN
#
# ## 👤 Quản lý hồ sơ người dùng (User/Profile Management)
# - Client First Name
# - Client Last Name
# - Profile Settings
# - Change Profile
# - Update Profile
# - User Account Settings
#
# ## 🏠 Địa chỉ (Address)
# - Add a New Address
# - Shipping Addresses
# - Delivery City
# - Delivery Country
# - Zip Code
#
# ...
